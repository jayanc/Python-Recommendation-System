# %%
# Import libraries
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Reading ratings file
ratings = pd.read_csv('ratings.csv', sep='\t', encoding='latin-1', 
                      usecols=['user_id', 'movie_id', 'user_emb_id', 'movie_emb_id', 'rating'],nrows=100000)
max_userid = ratings['user_id'].drop_duplicates().max()
max_movieid = ratings['movie_id'].drop_duplicates().max()

# Reading ratings file
users = pd.read_csv('users.csv', sep='\t', encoding='latin-1', 
                    usecols=['user_id', 'gender', 'zipcode', 'age_desc', 'occ_desc'],nrows=100000)

# Reading ratings file
movies = pd.read_csv('movies.csv', sep='\t', encoding='latin-1', 
                     usecols=['movie_id', 'title', 'genres'],nrows=100000)

# %%
#Rratings
print(ratings) 
# Create training set
shuffled_ratings = ratings.sample(frac=1.)

# Shuffling users
Users = shuffled_ratings['user_emb_id'].values
print ('Users:', Users, ', shape =', Users.shape)

# Shuffling movies
Movies = shuffled_ratings['movie_emb_id'].values
print ('Movies:', Movies, ', shape =', Movies.shape)

# Shuffling ratings
Ratings = shuffled_ratings['rating'].values
print( 'Ratings:', Ratings, ', shape =', Ratings.shape)
# Out:
#        user_id  movie_id  rating  user_emb_id  movie_emb_id
# 0            1      1193       5            0          1192
# 1            1       661       3            0           660
# 2            1       914       3            0           913
# 3            1      3408       4            0          3407
# 4            1      2355       5            0          2354
# 5            1      1197       3            0          1196
# 6            1      1287       5            0          1286
# 7            1      2804       5            0          2803
# 8            1       594       4            0           593
# 9            1       919       4            0           918
# 10           1       595       5            0           594
# 11           1       938       4            0           937
# 12           1      2398       4            0          2397
# 13           1      2918       4            0          2917
# 14           1      1035       5            0          1034
# 15           1      2791       4            0          2790
# 16           1      2687       3            0          2686
# 17           1      2018       4            0          2017
# 18           1      3105       5            0          3104
# 19           1      2797       4            0          2796
# 20           1      2321       3            0          2320
# 21           1       720       3            0           719
# 22           1      1270       5            0          1269
# 23           1       527       5            0           526
# 24           1      2340       3            0          2339
# 25           1        48       5            0            47
# 26           1      1097       4            0          1096
# 27           1      1721       4            0          1720
# 28           1      1545       4            0          1544
# 29           1       745       3            0           744
# ...        ...       ...     ...          ...           ...
# 99970      668      1197       5          667          1196
# 99971      668      3101       4          667          3100
# 99972      668      1370       3          667          1369
# 99973      668      1391       3          667          1390
# 99974      668      1732       3          667          1731
# 99975      668      1909       5          667          1908
# 99976      668      1917       4          667          1916
# 99977      668      1777       4          667          1776
# 99978      668       161       3          667           160
# 99979      668        16       3          667            15
# 99980      668       196       2          667           195
# 99981      668      2762       5          667          2761
# 99982      668       356       4          667           355
# 99983      668      2916       3          667          2915
# 99984      668        47       4          667            46
# 99985      668        50       5          667            49
# 99986      668       379       4          667           378
# 99987      669      1249       4          668          1248
# 99988      669      3793       5          668          3792
# 99989      669       720       5          668           719
# 99990      669      2995       1          668          2994
# 99991      669      2058       5          668          2057
# 99992      669       724       4          668           723
# 99993      669      2997       5          668          2996
# 99994      669      1259       4          668          1258
# 99995      669       585       4          668           584
# 99996      669       586       3          668           585
# 99997      669       587       3          668           586
# 99998      669       588       4          668           587
# 99999      669       589       5          668           588
#
# [100000 rows x 5 columns]
# Users: [ 35  75 201 ... 481   1 389] , shape = (100000,)
# Movies: [ 580 3709 1397 ... 1771 1596 2118] , shape = (100000,)
# Ratings: [4 2 3 ... 2 3 4] , shape = (100000,)

# %%
# Import Keras libraries
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
# Import CF Model Architecture
from CFModel import CFModel
# Out:
# Using TensorFlow backend.

# %%
# Define constants
K_FACTORS = 100 # The number of dimensional embeddings for movies and users
TEST_USER = 2 # A random test user (user_id = 2000)

# %%
# Define model
model = CFModel(max_userid, max_movieid, K_FACTORS)
# Compile the model using MSE as the loss function and the AdaMax learning algorithm
model.summary()
model.compile(loss='mse', optimizer='adamax',metrics=['accuracy'])
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# embedding_1 (Embedding)          (None, 1, 100)        66900       embedding_input_1[0][0]
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 100)           0           embedding_1[0][0]
# ____________________________________________________________________________________________________
# embedding_2 (Embedding)          (None, 1, 100)        395200      embedding_input_2[0][0]
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 100)           0           embedding_2[0][0]
# ====================================================================================================
# Total params: 462100
# ____________________________________________________________________________________________________

# %%
# Callbacks monitor the validation loss
# Save the model weights each time the validation loss has improved
callbacks = [EarlyStopping('val_loss', patience=2), 
             ModelCheckpoint('weights.h5', save_best_only=True)]

# Use 30 epochs, 90% training data, 10% validation data 
history = model.fit([Users, Movies], Ratings,nb_epoch=30, validation_split=.1, verbose=2, callbacks=callbacks)
# Out:
# Train on 90000 samples, validate on 10000 samples
# Epoch 1/30
# 52s - loss: 10.3527 - acc: 0.0498 - val_loss: 5.8085 - val_acc: 0.1429
# Epoch 2/30
# 51s - loss: 4.0265 - acc: 0.2117 - val_loss: 3.0161 - val_acc: 0.2597
# Epoch 3/30
# 52s - loss: 2.4122 - acc: 0.2880 - val_loss: 2.1507 - val_acc: 0.3030
# Epoch 4/30
# 52s - loss: 1.8231 - acc: 0.3193 - val_loss: 1.7660 - val_acc: 0.3272
# Epoch 5/30
# 57s - loss: 1.5448 - acc: 0.3372 - val_loss: 1.5623 - val_acc: 0.3393
# Epoch 6/30
# 74s - loss: 1.3918 - acc: 0.3465 - val_loss: 1.4415 - val_acc: 0.3448
# Epoch 7/30
# 73s - loss: 1.3012 - acc: 0.3528 - val_loss: 1.3663 - val_acc: 0.3502
# Epoch 8/30
# 73s - loss: 1.2395 - acc: 0.3562 - val_loss: 1.3127 - val_acc: 0.3552
# Epoch 9/30
# 73s - loss: 1.1996 - acc: 0.3600 - val_loss: 1.2769 - val_acc: 0.3573
# Epoch 10/30
# 73s - loss: 1.1705 - acc: 0.3626 - val_loss: 1.2500 - val_acc: 0.3602
# Epoch 11/30
# 73s - loss: 1.1495 - acc: 0.3627 - val_loss: 1.2302 - val_acc: 0.3604
# Epoch 12/30
# 73s - loss: 1.1337 - acc: 0.3639 - val_loss: 1.2138 - val_acc: 0.3625
# Epoch 13/30
# 73s - loss: 1.1221 - acc: 0.3645 - val_loss: 1.2022 - val_acc: 0.3642
# Epoch 14/30
# 73s - loss: 1.1127 - acc: 0.3664 - val_loss: 1.1952 - val_acc: 0.3624
# Epoch 15/30
# 73s - loss: 1.1043 - acc: 0.3665 - val_loss: 1.1858 - val_acc: 0.3646
# Epoch 16/30
# 73s - loss: 1.0978 - acc: 0.3668 - val_loss: 1.1794 - val_acc: 0.3636
# Epoch 17/30
# 73s - loss: 1.0928 - acc: 0.3659 - val_loss: 1.1752 - val_acc: 0.3646
# Epoch 18/30
# 74s - loss: 1.0885 - acc: 0.3680 - val_loss: 1.1699 - val_acc: 0.3652
# Epoch 19/30
# 74s - loss: 1.0846 - acc: 0.3676 - val_loss: 1.1649 - val_acc: 0.3648
# Epoch 20/30
# 73s - loss: 1.0818 - acc: 0.3676 - val_loss: 1.1633 - val_acc: 0.3651
# Epoch 21/30
# 73s - loss: 1.0789 - acc: 0.3680 - val_loss: 1.1593 - val_acc: 0.3665
# Epoch 22/30
# 73s - loss: 1.0767 - acc: 0.3682 - val_loss: 1.1582 - val_acc: 0.3657
# Epoch 23/30
# 73s - loss: 1.0744 - acc: 0.3685 - val_loss: 1.1553 - val_acc: 0.3645
# Epoch 24/30
# 73s - loss: 1.0729 - acc: 0.3686 - val_loss: 1.1510 - val_acc: 0.3672
# Epoch 25/30
# 73s - loss: 1.0710 - acc: 0.3690 - val_loss: 1.1502 - val_acc: 0.3676
# Epoch 26/30
# 73s - loss: 1.0701 - acc: 0.3693 - val_loss: 1.1487 - val_acc: 0.3635
# Epoch 27/30
# 73s - loss: 1.0690 - acc: 0.3690 - val_loss: 1.1484 - val_acc: 0.3660
# Epoch 28/30
# 73s - loss: 1.0685 - acc: 0.3684 - val_loss: 1.1468 - val_acc: 0.3675
# Epoch 29/30
# 73s - loss: 1.0671 - acc: 0.3694 - val_loss: 1.1476 - val_acc: 0.3655
# Epoch 30/30
# 73s - loss: 1.0662 - acc: 0.3690 - val_loss: 1.1455 - val_acc: 0.3667

# %%
# Show the best validation RMSE
min_val_loss, idx = min((val, idx) for (idx, val) in enumerate(history.history['val_loss']))
print('Minimum RMSE at epoch', '{:d}'.format(idx+1), '=', '{:.4f}'.format(math.sqrt(min_val_loss)))
# Out:
# Minimum RMSE at epoch 30 = 1.0703

# %%
# Use the pre-trained model
trained_model = CFModel(max_userid, max_movieid, K_FACTORS)
# Load weights
trained_model.load_weights('weights.h5')

# %%
# Pick a random test user
users[users['user_id'] == TEST_USER]
# Out:
#    user_id gender zipcode age_desc       occ_desc
# 1        2      M   70072      56+  self-employed

# %%
# Function to predict the ratings given User ID and Movie ID
def predict_rating(user_id, movie_id):
    return trained_model.rate(user_id - 1, movie_id - 1)

# %%
user_ratings = ratings[ratings['user_id'] == TEST_USER][['user_id', 'movie_id', 'rating']]
user_ratings['prediction'] = user_ratings.apply(lambda x: predict_rating(TEST_USER, x['movie_id']), axis=1)
user_ratings.sort_values(by='rating', 
                         ascending=False).merge(movies, 
                                                on='movie_id', 
                                                how='inner', 
                                                suffixes=['_u', '_m']).head(20)
# Out:
#     user_id  movie_id  rating  prediction  \
# 0         2      1357       5    3.733144
# 1         2      2236       5    3.722420
# 2         2      3147       5    3.714902
# 3         2      1293       5    3.693522
# 4         2       110       5    3.676620
# 5         2      3471       5    3.734725
# 6         2      1945       5    3.725213
# 7         2      1225       5    3.809141
# 8         2       515       5    3.625121
# 9         2       480       5    3.717022
# 10        2      1370       5    3.765652
# 11        2      1193       5    3.730245
# 12        2       590       5    3.642427
# 13        2      1196       5    3.649704
# 14        2       593       5    3.758864
# 15        2      1954       5    3.739441
# 16        2      1124       5    3.773468
# 17        2      1957       5    3.703073
# 18        2       380       5    3.745775
# 19        2      2501       5    3.659215
#
#                                                 title  \
# 0                                        Shine (1996)
# 1                                  Simon Birch (1998)
# 2                              Green Mile, The (1999)
# 3                                       Gandhi (1982)
# 4                                   Braveheart (1995)
# 5           Close Encounters of the Third Kind (1977)
# 6                            On the Waterfront (1954)
# 7                                      Amadeus (1984)
# 8                      Remains of the Day, The (1993)
# 9                                Jurassic Park (1993)
# 10                                  Die Hard 2 (1990)
# 11             One Flew Over the Cuckoo's Nest (1975)
# 12                          Dances with Wolves (1990)
# 13  Star Wars: Episode V - The Empire Strikes Back...
# 14                   Silence of the Lambs, The (1991)
# 15                                       Rocky (1976)
# 16                              On Golden Pond (1981)
# 17                            Chariots of Fire (1981)
# 18                                   True Lies (1994)
# 19                                 October Sky (1999)
#
#                                genres
# 0                       Drama|Romance
# 1                               Drama
# 2                      Drama|Thriller
# 3                               Drama
# 4                    Action|Drama|War
# 5                        Drama|Sci-Fi
# 6                         Crime|Drama
# 7                               Drama
# 8                               Drama
# 9             Action|Adventure|Sci-Fi
# 10                    Action|Thriller
# 11                              Drama
# 12            Adventure|Drama|Western
# 13  Action|Adventure|Drama|Sci-Fi|War
# 14                     Drama|Thriller
# 15                       Action|Drama
# 16                              Drama
# 17                              Drama
# 18    Action|Adventure|Comedy|Romance
# 19                              Drama

# %%
recommendations = ratings[ratings['movie_id'].isin(user_ratings['movie_id']) == False][['movie_id']].drop_duplicates()
recommendations['prediction'] = recommendations.apply(lambda x: predict_rating(TEST_USER, x['movie_id']), axis=1)
recommendations.sort_values(by='prediction',
                          ascending=False).merge(movies,
                                                 on='movie_id',
                                                 how='inner',
                                                 suffixes=['_u', '_m']).head(20)
# Out:
#     movie_id  prediction                                title  \
# 0       3719    4.039097          Love's Labour's Lost (2000)
# 1       1670    3.971614           Welcome To Sarajevo (1997)
# 2        484    3.961718                        Lassie (1994)
# 3       2652    3.959218    Curse of Frankenstein, The (1957)
# 4       3310    3.955760                      Kid, The (1921)
# 5       1743    3.946225             Arguing the World (1996)
# 6       3597    3.937067                       Whipped (2000)
# 7       1234    3.934803                    Sting, The (1973)
# 8       1482    3.923779                      Van, The (1996)
# 9       3496    3.917943              Madame Sousatzka (1988)
# 10      1703    3.916122          For Richer or Poorer (1997)
# 11      3318    3.916016                    Deterrence (1998)
# 12       458    3.913109  Geronimo: An American Legend (1993)
# 13      1938    3.910778             Lost Weekend, The (1945)
# 14      1187    3.910493                  Passion Fish (1992)
# 15      3858    3.905574             Cecil B. Demented (2000)
# 16      2786    3.901526             Haunted Honeymoon (1986)
# 17       229    3.901081          Death and the Maiden (1994)
# 18       945    3.895322                       Top Hat (1935)
# 19       583    3.894613      Dear Diary (Caro Diario) (1994)
#
#                     genres
# 0           Comedy|Romance
# 1                Drama|War
# 2     Adventure|Children's
# 3                   Horror
# 4                   Action
# 5              Documentary
# 6                   Comedy
# 7             Comedy|Crime
# 8             Comedy|Drama
# 9                    Drama
# 10                  Comedy
# 11                Thriller
# 12           Drama|Western
# 13                   Drama
# 14                   Drama
# 15                  Comedy
# 16                  Comedy
# 17          Drama|Thriller
# 18  Comedy|Musical|Romance
# 19            Comedy|Drama
